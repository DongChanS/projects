# %%
import pandas as pd
import numpy as np
from collections import Counter,OrderedDict
import tensorflow as tf
import datetime
from gensim.models import Word2Vec, KeyedVectors
from konlpy.tag import Okt
import random
import copy
from sklearn.model_selection import train_test_split
# Out:
# /home/dongchan/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
def basic_preprocessing(string):
    if string != string or type(string) == type(1) or string == ' ':
        return ''
    else:
        return string
    
DF['교정된 리뷰'] = DF['교정된 리뷰'].apply(basic_preprocessing)

def twitter(string):
    tagged_list = okt.pos(string,norm=True,stem=True) 
    
    if random.uniform(0,1) < 1e-3 and len(tagged_list) >= 5:
        print('--------------------')
        print('교정전 리뷰\n',string)
        print('\n교정후 리뷰\n','/'.join([x for x,y in tagged_list if y == 'Noun']))
        
    return [x for x,y in tagged_list if y == 'Noun']

tagged_review = DF['교정된 리뷰'].apply(twitter)

tagged_review.apply(lambda x : '/'.join(x)).to_csv('명사_형태소분석.csv')

# %%
DF = pd.read_csv('labeled_df.csv')

review_str_noun = pd.read_csv('명사_형태소분석.csv')

# %%
review_str_noun=review_str_noun.drop('0',axis=1)

# %%
review_str_noun.head(10)
# Out:
#                  Unnamed: 1
# 0                       NaN
# 1                       NaN
# 2                    점/만점/점
# 3             우파/루크/로스/개/보석
# 4                       NaN
# 5                       NaN
# 6  계속/다운/리소스/파일/접속/다시/설치/해도
# 7                       NaN
# 8              호루/근대/또/루루/좀
# 9                       NaN

# %%
DF
# Out:
#         Unnamed: 0  평점          시간                               이름  \
# 0           181637   5  2018-11-25                 우파루마운틴 for Kakao
# 1           181638   4  2018-11-25                 우파루마운틴 for Kakao
# 2           181639   4  2018-11-25                 우파루마운틴 for Kakao
# 3           181640   5  2018-11-25                 우파루마운틴 for Kakao
# 4           181641   5  2018-11-25                 우파루마운틴 for Kakao
# 5           181642   5  2018-11-25                 우파루마운틴 for Kakao
# 6           181643   5  2018-11-25                 우파루마운틴 for Kakao
# 7           181644   3  2018-11-25                 우파루마운틴 for Kakao
# 8           181645   5  2018-11-25                 우파루마운틴 for Kakao
# 9           181646   5  2018-11-25                 우파루마운틴 for Kakao
# 10          181647   1  2018-11-25                 우파루마운틴 for Kakao
# 11          181648   4  2018-11-25                 우파루마운틴 for Kakao
# 12          181649   5  2018-11-25                 우파루마운틴 for Kakao
# 13          181650   5  2018-11-25                 우파루마운틴 for Kakao
# 14          181651   1  2018-11-25                 우파루마운틴 for Kakao
# 15          181652   5  2018-11-25                 우파루마운틴 for Kakao
# 16          181653   5  2018-11-25                 우파루마운틴 for Kakao
# 17          181654   5  2018-11-24                 우파루마운틴 for Kakao
# 18          181655   5  2018-11-24                 우파루마운틴 for Kakao
# 19          181656   2  2018-11-24                 우파루마운틴 for Kakao
# 20          181657   1  2018-11-24                 우파루마운틴 for Kakao
# 21          181658   5  2018-11-24                 우파루마운틴 for Kakao
# 22          181659   5  2018-11-24                 우파루마운틴 for Kakao
# 23          181660   5  2018-11-24                 우파루마운틴 for Kakao
# 24          181661   1  2018-11-24                 우파루마운틴 for Kakao
# 25          181662   4  2018-11-24                 우파루마운틴 for Kakao
# 26          181663   5  2018-11-24                 우파루마운틴 for Kakao
# 27          181664   4  2018-11-24                 우파루마운틴 for Kakao
# 28          181665   5  2018-11-23                 우파루마운틴 for Kakao
# 29          181666   2  2018-11-23                 우파루마운틴 for Kakao
# ...            ...  ..         ...                              ...
# 407241      379029   5  2018-09-18  라스트 쉘터 (Last Shelter: Survival)
# 407242      379031   2  2018-09-18  라스트 쉘터 (Last Shelter: Survival)
# 407243      379032   5  2018-09-18  라스트 쉘터 (Last Shelter: Survival)
# 407244      379034   5  2018-09-18  라스트 쉘터 (Last Shelter: Survival)
# 407245      379035   5  2018-09-18  라스트 쉘터 (Last Shelter: Survival)
# 407246      379036   5  2018-09-18  라스트 쉘터 (Last Shelter: Survival)
# 407247      379037   5  2018-09-18  라스트 쉘터 (Last Shelter: Survival)
# 407248      379038   5  2018-09-17  라스트 쉘터 (Last Shelter: Survival)
# 407249      379040   4  2018-09-17  라스트 쉘터 (Last Shelter: Survival)
# 407250      379041   5  2018-09-17  라스트 쉘터 (Last Shelter: Survival)
# 407251      379042   2  2018-09-17  라스트 쉘터 (Last Shelter: Survival)
# 407252      379043   5  2018-09-17  라스트 쉘터 (Last Shelter: Survival)
# 407253      379044   5  2018-09-17  라스트 쉘터 (Last Shelter: Survival)
# 407254      379045   3  2018-09-17  라스트 쉘터 (Last Shelter: Survival)
# 407255      379046   5  2018-09-17  라스트 쉘터 (Last Shelter: Survival)
# 407256      379047   5  2018-09-17  라스트 쉘터 (Last Shelter: Survival)
# 407257      379048   5  2018-09-17  라스트 쉘터 (Last Shelter: Survival)
# 407258      379049   3  2018-09-17  라스트 쉘터 (Last Shelter: Survival)
# 407259      379050   5  2018-09-17  라스트 쉘터 (Last Shelter: Survival)
# 407260      379051   3  2018-09-17  라스트 쉘터 (Last Shelter: Survival)
# 407261      379052   4  2018-09-17  라스트 쉘터 (Last Shelter: Survival)
# 407262      379053   5  2018-09-17  라스트 쉘터 (Last Shelter: Survival)
# 407263      379054   5  2018-09-17  라스트 쉘터 (Last Shelter: Survival)
# 407264      379055   4  2018-09-17  라스트 쉘터 (Last Shelter: Survival)
# 407265      379056   4  2018-09-17  라스트 쉘터 (Last Shelter: Survival)
# 407266      379057   5  2018-09-17  라스트 쉘터 (Last Shelter: Survival)
# 407267      379058   4  2018-09-17  라스트 쉘터 (Last Shelter: Survival)
# 407268      379059   4  2018-09-17  라스트 쉘터 (Last Shelter: Survival)
# 407269      379060   5  2018-09-17  라스트 쉘터 (Last Shelter: Survival)
# 407270      379061   5  2018-09-17  라스트 쉘터 (Last Shelter: Survival)
#
#          timestamp                                             교정된 리뷰  length  \
# 0       1543071600                                                          1
# 1       1543071600                                                 좋음       2
# 2       1543071600                                              재미있어요       5
# 3       1543071600                            Num    점만점에    Num    점      10
# 4       1543071600            우파루크로스를개말고많이해주셨음 좋겠구요 , 보석도 많이주셨으면 좋겠어요      39
# 5       1543071600                                               재밌네요       4
# 6       1543071600                                                좋아오       3
# 7       1543071600  계속 다운받은 리소스 파일이 잘못되었다면서 접속이 안되네요 다시 설치 해도 안되는데...      56
# 8       1543071600                                               Num        5
# 9       1543071600               호루   !!   근대 또 루루 어떻게 만드는지좀    Elip       24
# 10      1543071600                                                  야       1
# 11      1543071600                캐릭터가넘비싸구 소환하는데 너무 오래걸리지만 좋아욘   ♡♡        31
# 12      1543071600                                              좋아여 ㅎ       5
# 13      1543071600  처음에는 재미없을줄알았는데 해보니까 헤이데이랑 비슷해서 재미있더라고요 예전이 했던 ...      67
# 14      1543071600  리소스파일에 문제가 있다고 계속 튕기네요    덕분에 게임 시작도 못해보고 접습니다...      47
# 15      1543071600                      인내심 기르는데 도움이 되요 ~  짱짱    !!        23
# 16      1543071600                                               너무조코       4
# 17      1542985200                                               ㅎㅎ         2
# 18      1542985200      Num    살때하던 추억의겜    Elip ㅠ 꿀잼이고 우파루들 너무 귀여움 ♥      34
# 19      1542985200                계속 리소스파일 설치라면서 꺼지네여 벌서    Num    일째      27
# 20      1542985200                                      이거는 현질만해야되여 ?      13
# 21      1542985200                                  정말 재밌고 유저분들도 해보세요      17
# 22      1542985200                      이거 보상도 많이 주고 한마디로 최고입니댱  ~ ♥       26
# 23      1542985200                                          재미있어요           7
# 24      1542985200                                        재미 없는 게임입니다      11
# 25      1542985200  일주일 미션  ( ? ) 그거 친구한테 씨앗주는 미션 있잖아요 친구한테 씨앗주고 친...     138
# 26      1542985200                                            괜찮기만이네요       7
# 27      1542985200                                                괜찮네       3
# 28      1542898800                                           귀욤재미있음 굿       8
# 29      1542898800                                       현질을 게속 유도합니다      12
# ...            ...                                                ...     ...
# 407241  1537196400                                      막 시작해서   ^^         9
# 407242  1537196400  왜 ! 자꾸 가속이 적용되지 않고 시간이 그대로 있고 버프만 없어집니까 ? 내 가속...      53
# 407243  1537196400                                              해보고싶음       5
# 407244  1537196400                                                  굿       1
# 407245  1537196400                                            뭔가 재미날듯       7
# 407246  1537196400                                                 잼남       2
# 407247  1537196400                                                좋네요       3
# 407248  1537110000                                           도저히 모루겟네       8
# 407249  1537110000                                                 잼남       2
# 407250  1537110000                                         지금까지는 마음에듬      10
# 407251  1537110000                아직은 잘모르겠음    기존게임과 다르게 할일이 많앗으면 좋겠음      34
# 407252  1537110000                                               꿀잼 ~       4
# 407253  1537110000                                                 꿀잼       2
# 407254  1537110000                                    걍그럼 보너스주니 남기는거임      15
# 407255  1537110000                                     해보는중입니다   ㅎㅎ        10
# 407256  1537110000                                      일단 재밋어보임 해보겟음      13
# 407257  1537110000                                           재밌네요 좋아요       8
# 407258  1537110000                                                  굿       1
# 407259  1537110000                                               신선하네       4
# 407260  1537110000                                                  굿       1
# 407261  1537110000                                                  굳       1
# 407262  1537110000                                                굿굿        2
# 407263  1537110000                                               재밌네요       4
# 407264  1537110000                                         일단은 흥미 있어여      10
# 407265  1537110000              기존 겜 빌드방식은 비슷하네요 더해봐야 알겠지만 그리 나쁘지는 않음      37
# 407266  1537110000                                                  굿       1
# 407267  1537110000                                                 고민       2
# 407268  1537110000                                     아기자기하고 괜찮아보입니다      14
# 407269  1537110000                                            ㅆ 휴가 오늘       7
# 407270  1537110000                                                재밌네       3
#
#         is_good
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# 6         False
# 7         False
# 8         False
# 9         False
# 10        False
# 11        False
# 12        False
# 13        False
# 14        False
# 15        False
# 16        False
# 17        False
# 18        False
# 19        False
# 20        False
# 21        False
# 22        False
# 23        False
# 24        False
# 25        False
# 26        False
# 27        False
# 28        False
# 29        False
# ...         ...
# 407241     True
# 407242     True
# 407243     True
# 407244     True
# 407245     True
# 407246     True
# 407247     True
# 407248     True
# 407249     True
# 407250     True
# 407251     True
# 407252     True
# 407253     True
# 407254     True
# 407255     True
# 407256     True
# 407257     True
# 407258     True
# 407259     True
# 407260     True
# 407261     True
# 407262     True
# 407263     True
# 407264     True
# 407265     True
# 407266     True
# 407267     True
# 407268     True
# 407269     True
# 407270     True
#
# [407271 rows x 8 columns]

# %%
def str_to_list(string):
    
    if string != string or len(string) == 0:
        return []
    else:
        return string.split('/')

tagged_review = review_str_noun[review_str_noun.columns[0]].apply(str_to_list)

# %%
tagged_review
# Out:
# 0                                                        []
# 1                                                        []
# 2                                                [점, 만점, 점]
# 3                                       [우파, 루크, 로스, 개, 보석]
# 4                                                        []
# 5                                                        []
# 6                         [계속, 다운, 리소스, 파일, 접속, 다시, 설치, 해도]
# 7                                                        []
# 8                                        [호루, 근대, 또, 루루, 좀]
# 9                                                        []
# 10                                           [캐릭터, 소환, 좋아욘]
# 11                                                       []
# 12                                    [처음, 헤이데, 예전, 게임, 정말]
# 13                       [리소스, 파일, 문제, 계속, 튕기네, 덕분, 게임, 시작]
# 14                                            [인내심, 도움, 짱짱]
# 15                                                  [무조, 코]
# 16                                                       []
# 17                                   [살때, 추억, 겜, 꿀잼, 파루, 움]
# 18                                  [계속, 리소스, 파일, 지네, 벌, 일]
# 19                                               [거, 현질, 여]
# 20                                                 [정말, 유저]
# 21                                      [거, 보상, 한마디, 최고, 댱]
# 22                                                       []
# 23                                                 [재미, 게임]
# 24        [일주일, 미션, 그거, 친구, 씨앗, 미션, 친구, 씨앗, 친구, 씨앗, 재배, ...
# 25                                                      [네]
# 26                                                       []
# 27                                                   [욤, 굿]
# 28                                             [현질, 게속, 유도]
# 29                                             [추억, 다시, 시작]
#                                 ...
# 407240                                              [막, 시작]
# 407241              [왜, 자꾸, 가속, 적용, 시간, 그대로, 버프, 내, 가속, 버프]
# 407242                                                   []
# 407243                                                  [굿]
# 407244                                             [뭔가, 재미]
# 407245                                                 [잼남]
# 407246                                                   []
# 407247                                           [도저히, 모루겟]
# 407248                                                 [잼남]
# 407249                                          [지금, 마음, 듬]
# 407250                                      [은, 기존, 게임, 일이]
# 407251                                                 [꿀잼]
# 407252                                                 [꿀잼]
# 407253                                         [보너스, 주니, 임]
# 407254                                                  [중]
# 407255                                             [일단, 보임]
# 407256                                                   []
# 407257                                                  [굿]
# 407258                                                   []
# 407259                                                  [굿]
# 407260                                                   []
# 407261                                                 [굿굿]
# 407262                                                   []
# 407263                                             [일단, 흥미]
# 407264                                     [기존, 겜, 빌드방식, 더]
# 407265                                                  [굿]
# 407266                                                 [고민]
# 407267                                                   []
# 407268                                             [휴가, 오늘]
# 407269                                                   []
# Name: Unnamed: 1, Length: 407270, dtype: object

# %%
review_model = Word2Vec(tagged_review, size=200, window = 5, workers=6, iter=10, sg=1)

review_vector = review_model.wv
review_vocab = review_vector.vocab

# 카운팅 객체(나중에 쓸거임)
w2c_review = dict()
for item in sorted(review_vocab,key=review_vocab.get,reverse=True):
    w2c_review[item]=review_vocab[item].count

# %%
noun_freq = pd.DataFrame.from_dict(w2c_review,orient='index')

noun_freq.to_excel('명사빈도순위.xlsx')

# %%
noun_freq

# 이걸 기반으로 분석할 명사들을 선정함

with open('game_nouns','r') as fileobj:
    string = fileobj.read()

# %%
keywords = string.split('\n')[:-1]

# %%
keywords_freq = noun_freq.loc[keywords]

# %%
keywords_freq
# Out:
#           0
# 게임    80629
# 겜     17301
# 시간    14314
# 현질    12369
# 업데이트  12184
# 재미    12061
# 유저    10627
# 사람     7294
# 접속    10445
# 돈      8629
# 계정     8327
# 과금     7300
# 캐릭터    6984
# 이벤트    6432
# 렉      6348
# 오류     6243
# 버그     3849
# 플레이    5658
# 그래픽    5388
# 보상     5275
# 서버     5237
# 레벨     5120
# 광고     5104
# 삭제     5043
# 화면     4893
# 폰      4840
# 로딩     4662
# 유도     4595
# 설치     4258
# 해결     4184
# 문제     4150
# 로그인    4119
# 다운     4090
# 결제     3892
# 스토리    3817
# 실행     3777
# 아이템    3635
# 복구     3630
# 수정     3401
# 용량     3621
# 확률     3609
# 카드     3467
# 운영     3382

# %%
# 이걸로 idf를 만들면됨.
keywords_freq.head(10)
# idf를 만들기 위해서 total count를 계산하자.
total_count = keywords_freq.sum()[0]
print("total count\n",total_count)
# idf 만들기
idf_dict = np.log(total_count/keywords_freq)[0].to_dict()
idf_dict
# Out:
# total count
#  344183
# {'게임': 1.4513151063797365,
#  '겜': 2.990409189366734,
#  '시간': 3.1799354133517133,
#  '현질': 3.3259801502752464,
#  '업데이트': 3.3410498770752586,
#  '재미': 3.3511963860670133,
#  '유저': 3.477775560277561,
#  '사람': 3.8541214002816306,
#  '접속': 3.49505009765959,
#  '돈': 3.6860448691419485,
#  '계정': 3.721670245414437,
#  '과금': 3.8532991445137736,
#  '캐릭터': 3.8975516741308183,
#  '이벤트': 3.979887960791454,
#  '렉': 3.9930336900039567,
#  '오류': 4.009712656588512,
#  '버그': 4.49336011836651,
#  '플레이': 4.108103019788744,
#  '그래픽': 4.1569992341200015,
#  '보상': 4.178194813305989,
#  '서버': 4.185424677370769,
#  '레벨': 4.208019053616703,
#  '광고': 4.211148946625631,
#  '삭제': 4.223172349573531,
#  '화면': 4.253367880361132,
#  '폰': 4.264258771939579,
#  '로딩': 4.301728952054554,
#  '유도': 4.316204736860469,
#  '설치': 4.392373926196831,
#  '해결': 4.409905765905497,
#  '문제': 4.418065158425512,
#  '로그인': 4.425563077214176,
#  '다운': 4.432628522613409,
#  '결제': 4.48225032834436,
#  '스토리': 4.501708718905027,
#  '실행': 4.5122434489378,
#  '아이템': 4.550564381682636,
#  '복구': 4.55194084439136,
#  '수정': 4.617103986643061,
#  '용량': 4.554423261884615,
#  '확률': 4.5577427670074675,
#  '카드': 4.597883825965233,
#  '운영': 4.622706242191731}

# %%
keyword_index = {y:x for x,y in enumerate(idf_dict.keys())}
inv_dict = list(idf_dict.keys())

# %%
def extract(words):
    
    return [w for w in words if w in keywords]

extract_nouns = tagged_review.apply(extract)

# %%
extract_nouns.head(10)
# Out:
# 0              []
# 1              []
# 2              []
# 3              []
# 4              []
# 5              []
# 6    [다운, 접속, 설치]
# 7              []
# 8              []
# 9              []
# Name: Unnamed: 1, dtype: object

# %%
extract_nouns_str = extract_nouns.apply(lambda x :
                                       '/'.join([str(keyword_index[w]) for w in x]))

DF['문자열'] = extract_nouns_str

# %%
COPY = DF[['문자열','이름','is_good']]

GROUP_BY_GAME = COPY.groupby(['이름'])

keys = list(GROUP_BY_GAME.groups.keys())
indices = list(GROUP_BY_GAME.groups.values())

DFs = [COPY.loc[indices[x]] for x in range(len(indices))]

# %%
DFs[0]
# Out:
#                      문자열                              이름  is_good
# 196019                38  2018갓오브하이스쿨 with NAVER WEBTOON    False
# 196020                10  2018갓오브하이스쿨 with NAVER WEBTOON    False
# 196021                    2018갓오브하이스쿨 with NAVER WEBTOON    False
# 196022                 0  2018갓오브하이스쿨 with NAVER WEBTOON    False
# 196023                    2018갓오브하이스쿨 with NAVER WEBTOON    False
# 196024                    2018갓오브하이스쿨 with NAVER WEBTOON    False
# 196025                 1  2018갓오브하이스쿨 with NAVER WEBTOON    False
# 196026                13  2018갓오브하이스쿨 with NAVER WEBTOON    False
# 196027                    2018갓오브하이스쿨 with NAVER WEBTOON    False
# 196028                    2018갓오브하이스쿨 with NAVER WEBTOON    False
# 196029                    2018갓오브하이스쿨 with NAVER WEBTOON    False
# 196030             4/4/8  2018갓오브하이스쿨 with NAVER WEBTOON    False
# 196031              0/26  2018갓오브하이스쿨 with NAVER WEBTOON    False
# 196032                    2018갓오브하이스쿨 with NAVER WEBTOON    False
# 196033                    2018갓오브하이스쿨 with NAVER WEBTOON    False
# 196034               0/8  2018갓오브하이스쿨 with NAVER WEBTOON    False
# 196035                    2018갓오브하이스쿨 with NAVER WEBTOON    False
# 196036              6/17  2018갓오브하이스쿨 with NAVER WEBTOON    False
# 196037                    2018갓오브하이스쿨 with NAVER WEBTOON    False
# 196038                    2018갓오브하이스쿨 with NAVER WEBTOON    False
# 196039                    2018갓오브하이스쿨 with NAVER WEBTOON    False
# 196040                    2018갓오브하이스쿨 with NAVER WEBTOON    False
# 196041                    2018갓오브하이스쿨 with NAVER WEBTOON    False
# 196042                    2018갓오브하이스쿨 with NAVER WEBTOON    False
# 196043                 1  2018갓오브하이스쿨 with NAVER WEBTOON    False
# 196044                 0  2018갓오브하이스쿨 with NAVER WEBTOON    False
# 196045                 1  2018갓오브하이스쿨 with NAVER WEBTOON    False
# 196046                    2018갓오브하이스쿨 with NAVER WEBTOON    False
# 196047                 1  2018갓오브하이스쿨 with NAVER WEBTOON    False
# 196048          6/0/35/0  2018갓오브하이스쿨 with NAVER WEBTOON    False
# ...                  ...                             ...      ...
# 200590                    2018갓오브하이스쿨 with NAVER WEBTOON    False
# 200591              0/40  2018갓오브하이스쿨 with NAVER WEBTOON    False
# 200592                    2018갓오브하이스쿨 with NAVER WEBTOON    False
# 200593                    2018갓오브하이스쿨 with NAVER WEBTOON    False
# 200594                    2018갓오브하이스쿨 with NAVER WEBTOON    False
# 200595                    2018갓오브하이스쿨 with NAVER WEBTOON    False
# 200596                    2018갓오브하이스쿨 with NAVER WEBTOON    False
# 200597             13/13  2018갓오브하이스쿨 with NAVER WEBTOON    False
# 200598                 1  2018갓오브하이스쿨 with NAVER WEBTOON    False
# 200599                    2018갓오브하이스쿨 with NAVER WEBTOON    False
# 200600                 1  2018갓오브하이스쿨 with NAVER WEBTOON    False
# 200601                    2018갓오브하이스쿨 with NAVER WEBTOON    False
# 200602                24  2018갓오브하이스쿨 with NAVER WEBTOON    False
# 200603                    2018갓오브하이스쿨 with NAVER WEBTOON    False
# 200604                17  2018갓오브하이스쿨 with NAVER WEBTOON    False
# 200605                    2018갓오브하이스쿨 with NAVER WEBTOON    False
# 200606                    2018갓오브하이스쿨 with NAVER WEBTOON    False
# 200607                    2018갓오브하이스쿨 with NAVER WEBTOON    False
# 200608                    2018갓오브하이스쿨 with NAVER WEBTOON    False
# 200609                    2018갓오브하이스쿨 with NAVER WEBTOON    False
# 200610                32  2018갓오브하이스쿨 with NAVER WEBTOON    False
# 200611                    2018갓오브하이스쿨 with NAVER WEBTOON    False
# 200612                    2018갓오브하이스쿨 with NAVER WEBTOON    False
# 200613          12/13/12  2018갓오브하이스쿨 with NAVER WEBTOON    False
# 200614                    2018갓오브하이스쿨 with NAVER WEBTOON    False
# 200615  32/32/8/32/32/42  2018갓오브하이스쿨 with NAVER WEBTOON    False
# 200616                    2018갓오브하이스쿨 with NAVER WEBTOON    False
# 200617           18/34/0  2018갓오브하이스쿨 with NAVER WEBTOON    False
# 200618                 0  2018갓오브하이스쿨 with NAVER WEBTOON    False
# 200619                    2018갓오브하이스쿨 with NAVER WEBTOON    False
#
# [4601 rows x 3 columns]

# %%
import operator

def basic_preprocessing(string):
    if string != string or type(string) == type(1) or string == ' ':
        return ''
    else:
        return string

df_list = []
for df in DFs:
    
    label = df['is_good'].values[0]
    game_name = df['이름'].values[0]
    print(game_name,':',label)
    
    df['문자열'] = df['문자열'].apply(basic_preprocessing)
    tokens = '/'.join(df['문자열']).split('/')
    Count_review = Counter([x for x in tokens if len(x) != 0])
    tf_idf = {int(x):idf_dict[inv_dict[int(x)]]*np.log(y+1) for x,y in Count_review.items()}
    sorted_tfidf = sorted(tf_idf.items(), key=operator.itemgetter(0))
    sorted_tfidf = [(inv_dict[x],y) for x,y in sorted_tfidf] + [('is_good',label)]
    df_ = pd.DataFrame(sorted_tfidf,columns=[0,game_name])
    df_ = df_.set_index(0).T
    df_list.append(df_)
    
full_vector = pd.concat(df_list)
# Out:
# 2018갓오브하이스쿨 with NAVER WEBTOON : False
# FINAL FANTASY BRAVE EXVIUS : False
# Idle Heroes - 아이들 히어로즈 : False
# Mobile Strike : False
# Sdorica - sunset - (스도리카 -선셋-) : False
# War Machines: 탱크 게임 - 무료 : False
# Yu-Gi-Oh! Duel Links : False
#  Jurassic World™: The Game : False
# 검과마법 for Kakao : False
# 권력:THERULERS : False
# 낚시의 신 : False
# 냥코 대전쟁 : False
# 넷마블 포커 - 바카라, 7포커, 로우바둑이, 뉴포커 : True
# 노블레스 with NAVER WEBTOON : False
# 놀러와 마이홈 : False
# 다크어벤저3 : False
# 더 킹 오브 파이터즈98 UM온라인 for kakao : False
# 도미네이션즈 : False
# 라스트 쉘터 (Last Shelter: Survival) : True
# 라스트 엠파이어 워 Z : False
# 레알팜 : False
# 레이븐: SIGN : False
# 로드 모바일: 제국의 전쟁 - MMORPG : True
# 리니지2 레볼루션 : True
# 리니지M : True
# 마스터 오브 이터니티 : False
# 마피아 시티 : True
# 매직 러쉬:히어로즈(Magic Rush: Heroes) : False
# 메이플스토리M : False
# 모두의마블 for kakao : True
# 몬스터 길들이기 for kakao : False
# 몬스터슈퍼리그 : False
# 뮤오리진 : False
# 반지 : False
# 별이되어라! : False
# 사커스피리츠 : False
# 삼국블레이드 : False
# 삼국지 조조전 Online : False
# 섀도우버스(Shadowverse) : False
# 서머너즈 워: 천공의 아레나 : True
# 세븐나이츠 for Kakao : True
# 소녀전선 : False
# 소드 아트 온라인　-메모리 디프래그- : False
# 스페셜솔져 - 모바일FPS : False
# 신의 탑-하늘의 정원 　AVABEL Online : False
# 심시티빌드잇 : False
# 아이러브니키 for kakao : False
# 아쿠아스토리 : False
# 애니팡 맞고 for kakao : False
# 애니팡 사천성 : False
# 애니팡 포커 for kakao : False
# 애니팡2 : False
# 애니팡3 : False
# 에브리타운 for Kakao : False
# 엘크로니클 : False
# 여명 for kakao : False
# 열혈강호 for kakao : False
# 영웅 for Kakao : False
# 오버히트 : False
# 오션 앤 엠파이어 : False
# 우파루마운틴 for Kakao : False
# 음양사 for kakao : False
# 이사만루2018 : True
# 좀비고등학교 : False
# 진·삼국무쌍: 언리쉬드 : False
# 짐의강산 : False
# 총기시대 (Guns of Glory) : True
# 캔디크러쉬소다 : False
# 컴투스프로야구 for 매니저 : False
# 컴투스프로야구2018 : True
# 쿠키런: 오븐브레이크 : True
# 크루세이더 퀘스트 : False
# 크리티카: 천상의 기사단 : False
# 클래시 오브 클랜 : True
# 클래시 오브 킹즈 (Clash of kings) : 기적 강림 : False
# 클랜즈:달의 그림자 : False
# 클럽 오디션 : False
# 킹덤스토리: 삼국지 RPG : False
# 킹스레이드 : True
# 킹오브아발론: 드래곤 전쟁 : False
# 테라M : False
# 파이널 블레이드 : False
# 파이널 판타지 XV: 새로운 제국 [Final Fantasy XV] : True
# 페이트/그랜드 오더 : False
# 펜타스톰 for kakao(5v5) : False
# 프렌즈팝 : False
# 프로야구 H2 : False
# 프리스타일2:플라잉덩크 : False
# 피망 뉴맞고 : 대한민국 1등 고스톱 : False
# 피망 섯다 : False
# 피망 포커 : 카지노 로얄 for kakao : False
# 피망 포커: 카지노 로얄 (7포커, 로우바둑이, 하이로우) : True
# 하스스톤 : True
# 한게임 신맞고 : 국가대표 무료고스톱 : False
# 한게임 포커 : True
# 해전1942 : False
# /home/dongchan/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:26: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False

# %%
labels, vector = full_vector['is_good'], full_vector.drop('is_good',axis=1)
vector = vector.fillna(4)

# %%
labels = labels.astype('int')

# %%
from sklearn import tree

# %%
clf = tree.DecisionTreeClassifier(criterion='entropy',max_depth=5,max_leaf_nodes=8)
clf = clf.fit(vector, labels.values)

# %%
from sklearn.metrics import accuracy_score

y_pred_tr = clf.predict(vector)
print('Accuracy: %.2f' % accuracy_score(labels.values, y_pred_tr))
# Out:
# Accuracy: 0.97

# %%
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn import tree
from sklearn.datasets import load_wine
from IPython.display import SVG
from graphviz import Source
from IPython.display import display

graph = tree.export_graphviz(clf, out_file='tree.dot'
   , feature_names=full_vector.columns[1:], class_names=['망겜','흥겜'] 
   , filled = True, rounded = True, proportion = False)

# %%
import pydotplus
graph = pydotplus.graph_from_dot_data(graph)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-e6186128d9ad> in <module>()
#       1 import pydotplus
# ----> 2 graph = pydotplus.graph_from_dot_data(graph)
#
# ~/anaconda3/lib/python3.6/site-packages/pydotplus/graphviz.py in graph_from_dot_data(data)
#     300     """
#     301
# --> 302     return parser.parse_dot_data(data)
#     303
#     304
#
# ~/anaconda3/lib/python3.6/site-packages/pydotplus/parser.py in parse_dot_data(data)
#     556             graphparser.parseWithTabs()
#     557
# --> 558         tokens = graphparser.parseString(data)
#     559
#     560         if len(tokens) == 1:
#
# ~/anaconda3/lib/python3.6/site-packages/pyparsing.py in parseString(self, instring, parseAll)
#    1620             instring = instring.expandtabs()
#    1621         try:
# -> 1622             loc, tokens = self._parse( instring, 0 )
#    1623             if parseAll:
#    1624                 loc = self.preParse( instring, loc )
#
# ~/anaconda3/lib/python3.6/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1371         else:
#    1372             if callPreParse and self.callPreparse:
# -> 1373                 preloc = self.preParse( instring, loc )
#    1374             else:
#    1375                 preloc = loc
#
# ~/anaconda3/lib/python3.6/site-packages/pyparsing.py in preParse(self, instring, loc)
#    1328     def preParse( self, instring, loc ):
#    1329         if self.ignoreExprs:
# -> 1330             loc = self._skipIgnorables( instring, loc )
#    1331
#    1332         if self.skipWhitespace:
#
# ~/anaconda3/lib/python3.6/site-packages/pyparsing.py in _skipIgnorables(self, instring, loc)
#    1320                 try:
#    1321                     while 1:
# -> 1322                         loc,dummy = e._parse( instring, loc )
#    1323                         exprsFound = True
#    1324                 except ParseException:
#
# ~/anaconda3/lib/python3.6/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1377             if self.mayIndexError or loc >= len(instring):
#    1378                 try:
# -> 1379                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1380                 except IndexError:
#    1381                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# ~/anaconda3/lib/python3.6/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    3715     def parseImpl( self, instring, loc, doActions=True ):
#    3716         if self.expr is not None:
# -> 3717             return self.expr._parse( instring, loc, doActions, callPreParse=False )
#    3718         else:
#    3719             raise ParseException("",loc,self.errmsg,self)
#
# ~/anaconda3/lib/python3.6/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1377             if self.mayIndexError or loc >= len(instring):
#    1378                 try:
# -> 1379                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1380                 except IndexError:
#    1381                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# ~/anaconda3/lib/python3.6/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    3528         for e in self.exprs:
#    3529             try:
# -> 3530                 ret = e._parse( instring, loc, doActions )
#    3531                 return ret
#    3532             except ParseException as err:
#
# ~/anaconda3/lib/python3.6/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1371         else:
#    1372             if callPreParse and self.callPreparse:
# -> 1373                 preloc = self.preParse( instring, loc )
#    1374             else:
#    1375                 preloc = loc
#
# ~/anaconda3/lib/python3.6/site-packages/pyparsing.py in preParse(self, instring, loc)
#    1332         if self.skipWhitespace:
#    1333             wt = self.whiteChars
# -> 1334             instrlen = len(instring)
#    1335             while loc < instrlen and instring[loc] in wt:
#    1336                 loc += 1
#
# TypeError: object of type 'NoneType' has no len()

# %%
from IPython.display import Image
Image(graph.create_png())
# Out:
# ---------------------------------------------------------------------------
# InvocationException                       Traceback (most recent call last)
# <ipython-input-46-f526efab5207> in <module>()
#       1 from IPython.display import Image
# ----> 2 Image(graph.create_png())
#
# ~/anaconda3/lib/python3.6/site-packages/pydotplus/graphviz.py in <lambda>(f, prog)
#    1795             self.__setattr__(
#    1796                 'create_' + frmt,
# -> 1797                 lambda f=frmt, prog=self.prog: self.create(format=f, prog=prog)
#    1798             )
#    1799             f = self.__dict__['create_' + frmt]
#
# ~/anaconda3/lib/python3.6/site-packages/pydotplus/graphviz.py in create(self, prog, format)
#    1958             if self.progs is None:
#    1959                 raise InvocationException(
# -> 1960                     'GraphViz\'s executables not found')
#    1961
#    1962         if prog not in self.progs:
#
# InvocationException: GraphViz's executables not found
